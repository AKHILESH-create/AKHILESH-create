# %% [markdown]
# <a href="https://colab.research.google.com/github/AKHILESH-create/AKHILESH-create/blob/main/AI_Training9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# SIMPLE LINEAR REGRESSION

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("Salary_Data.csv")
df.head(2)
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 612.0 bytes

# %%
df.isnull().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
x=df[['YearsExperience']]
y=df[['Salary']]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=0)

# %%
print("Shape of x_train: ", x_train.shape)
print("Shape of y_train: ", y_train.shape)
# Out:
# Shape of x_train:  (22, 1)
# Shape of y_train:  (22, 1)

# %%
print("Shape of x_test: ", x_test.shape)
print("Shape of y_test: ", y_test.shape)
# Out:
# Shape of x_test:  (8, 1)
# Shape of y_test:  (8, 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %% [markdown]
# FITTING TRAINING DATA INTO LINEAR REGRESSION

# %%
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
#prediction of Test and Training set result
y_pred=lr.predict(x_test)
y_pred=lr.predict(x_train)

# %%
#Visualizing Training dataset
plt.scatter(x_train,y_train,color="red")
plt.plot(x_train,y_pred,color="blue")
plt.show()

# %%
#Calculate Score of Model
lr.score(x_test,y_test)
# Out:
# 0.9779208335417602

# %%
#Visualizing Testing dataset
plt.scatter(x_test,y_test,color="red")
plt.plot(x_train,y_pred,color="blue")
plt.show()

# %% [markdown]
# y=mx+b

# %%
#coefficient
m=lr.coef_
m
# Out:
# array([[9379.71049195]])

# %%
#intercept
b=lr.intercept_
b
# Out:
# array([26986.69131674])

# %%
#y=mx+b
y1=m*1.5+b
y1
# Out:
# array([[41056.25705466]])

# %%
df.head()
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731
# 3              2.0   43525
# 4              2.2   39891

# %%
y1=m*1.1+b
y1
# Out:
# array([[37304.37285788]])

# %%
y2=m*2.2+b
y2
# Out:
# array([[47622.05439902]])

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
y_pred=lr.predict(x_test)
y_pred
# Out:
# array([[ 41056.25705466],
#        [123597.70938378],
#        [ 65443.50433372],
#        [ 63567.56223533],
#        [116093.94099022],
#        [108590.17259667],
#        [117031.91203942],
#        [ 64505.53328452]])

# %% [markdown]
# Mean absolute Error (MAE)

# %%
# Mean absolute Error (MAE)
print("MAE Value: ", mean_absolute_error(y_test,y_pred))
# Out:
# MAE Value:  3508.5455930660555

# %%
#MSE
print("MSE VAlue: ",mean_squared_error(y_test,y_pred))
# Out:
# MSE VAlue:  22407940.143340684

# %%
#RSME
print("RMSE Value: ",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# RMSE Value:  4733.70258289858

# %%
from sklearn.metrics import r2_score

# %%
print("R2_Score: ", r2_score(y_test,y_pred))
# Out:
# R2_Score:  0.9779208335417602
